# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder
import matplotlib.pyplot as plt
import seaborn as sea

myMovies=pd.read_csv("D:/Sampada/Sampada/Assignments/Association Rules/my_movies.csv")
myMovies.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\rcmod.py:82: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) >= "3.0":
# C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
#             V1       V2             V3          V4     V5  Sixth Sense  \
# 0  Sixth Sense    LOTR1  Harry Potter1  Green Mile  LOTR2            1
# 1    Gladiator  Patriot     Braveheart         NaN    NaN            0
# 2        LOTR1    LOTR2            NaN         NaN    NaN            0
# 3    Gladiator  Patriot    Sixth Sense         NaN    NaN            1
# 4    Gladiator  Patriot    Sixth Sense         NaN    NaN            1
#
#    Gladiator  LOTR1  Harry Potter1  Patriot  LOTR2  Harry Potter2  LOTR  \
# ...

# %%
frequent_items=apriori(myMovies.iloc[:,5:15],min_support=0.3,use_colnames=True)
frequent_items
# Out:
# C:\Users\Vitthal\AppData\Roaming\Python\Python39\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#    support                           itemsets
# 0      0.6                      (Sixth Sense)
# 1      0.7                        (Gladiator)
# 2      0.6                          (Patriot)
# 3      0.5           (Gladiator, Sixth Sense)
# 4      0.4             (Patriot, Sixth Sense)
# 5      0.6               (Gladiator, Patriot)
# 6      0.4  (Gladiator, Patriot, Sixth Sense)

# %%
#frequent_items.describe()
plt.plot(frequent_items.support)

# %%
sea.distplot(frequent_items.support)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='support', ylabel='Density'>

# %%
frequent_items=apriori(myMovies.iloc[:,5:15],min_support=0.2,use_colnames=True)
frequent_items
# Out:
# C:\Users\Vitthal\AppData\Roaming\Python\Python39\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                           itemsets
# 0       0.6                      (Sixth Sense)
# 1       0.7                        (Gladiator)
# 2       0.2                            (LOTR1)
# 3       0.2                    (Harry Potter1)
# 4       0.6                          (Patriot)
# 5       0.2                            (LOTR2)
# 6       0.2                       (Green Mile)
# 7       0.5           (Gladiator, Sixth Sense)
# 8       0.4             (Patriot, Sixth Sense)
# 9       0.2          (Green Mile, Sixth Sense)
# 10      0.6               (Gladiator, Patriot)
# 11      0.2                     (LOTR1, LOTR2)
# 12      0.4  (Gladiator, Patriot, Sixth Sense)

# %%
plt.plot(frequent_items.support)

# %%
sea.distplot(frequent_items.support)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='support', ylabel='Density'>

# %%
frequent_items=apriori(myMovies.iloc[:,5:15],min_support=0.1,use_colnames=True)
frequent_items
# Out:
# C:\Users\Vitthal\AppData\Roaming\Python\Python39\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                                           itemsets
# 0       0.6                                      (Sixth Sense)
# 1       0.7                                        (Gladiator)
# 2       0.2                                            (LOTR1)
# 3       0.2                                    (Harry Potter1)
# 4       0.6                                          (Patriot)
# 5       0.2                                            (LOTR2)
# 6       0.1                                    (Harry Potter2)
# 7       0.1                                             (LOTR)
# 8       0.1                                       (Braveheart)
# ...

# %%
plt.plot(frequent_items.support)

# %%
sea.distplot(frequent_items.support)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='support', ylabel='Density'>

# %%
frequent_items=apriori(myMovies.iloc[:,5:15],min_support=0.1,use_colnames=True,max_len=1)
frequent_items
# Out:
# C:\Users\Vitthal\AppData\Roaming\Python\Python39\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#    support         itemsets
# 0      0.6    (Sixth Sense)
# 1      0.7      (Gladiator)
# 2      0.2          (LOTR1)
# 3      0.2  (Harry Potter1)
# 4      0.6        (Patriot)
# 5      0.2          (LOTR2)
# 6      0.1  (Harry Potter2)
# 7      0.1           (LOTR)
# 8      0.1     (Braveheart)
# 9      0.2     (Green Mile)

# %%
frequent_items=apriori(myMovies.iloc[:,5:15],min_support=0.1,use_colnames=True,max_len=2)
frequent_items
# Out:
# C:\Users\Vitthal\AppData\Roaming\Python\Python39\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                        itemsets
# 0       0.6                   (Sixth Sense)
# 1       0.7                     (Gladiator)
# 2       0.2                         (LOTR1)
# 3       0.2                 (Harry Potter1)
# 4       0.6                       (Patriot)
# 5       0.2                         (LOTR2)
# 6       0.1                 (Harry Potter2)
# 7       0.1                          (LOTR)
# 8       0.1                    (Braveheart)
# 9       0.2                    (Green Mile)
# 10      0.5        (Gladiator, Sixth Sense)
# 11      0.1            (LOTR1, Sixth Sense)
# 12      0.1    (Harry Potter1, Sixth Sense)
# ...

# %%
frequent_items=apriori(myMovies.iloc[:,5:15],min_support=0.1,use_colnames=True,max_len=3)
frequent_items
# Out:
# C:\Users\Vitthal\AppData\Roaming\Python\Python39\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                                  itemsets
# 0       0.6                             (Sixth Sense)
# 1       0.7                               (Gladiator)
# 2       0.2                                   (LOTR1)
# 3       0.2                           (Harry Potter1)
# 4       0.6                                 (Patriot)
# 5       0.2                                   (LOTR2)
# 6       0.1                           (Harry Potter2)
# 7       0.1                                    (LOTR)
# 8       0.1                              (Braveheart)
# 9       0.2                              (Green Mile)
# 10      0.5                  (Gladiator, Sixth Sense)
# ...

# %%
rules=association_rules(frequent_items,metric="lift",min_threshold=0.7)
rules
# Out:
#                      antecedents                  consequents  \
# 0                    (Gladiator)                (Sixth Sense)
# 1                  (Sixth Sense)                  (Gladiator)
# 2                        (LOTR1)                (Sixth Sense)
# 3                  (Sixth Sense)                      (LOTR1)
# 4                (Harry Potter1)                (Sixth Sense)
# ..                           ...                          ...
# 131  (Harry Potter1, Green Mile)                      (LOTR2)
# 132          (LOTR2, Green Mile)              (Harry Potter1)
# 133              (Harry Potter1)          (LOTR2, Green Mile)
# 134                      (LOTR2)  (Harry Potter1, Green Mile)
# 135                 (Green Mile)       (Harry Potter1, LOTR2)
#
#      antecedent support  consequent support  support  confidence      lift  \
# 0                   0.7                 0.6      0.5    0.714286  1.190476
# ...

# %%
rules.sort_values('lift',ascending=False)
# Out:
#                    antecedents                   consequents  \
# 106    (Gladiator, Green Mile)                        (LOTR)
# 111                     (LOTR)       (Gladiator, Green Mile)
# 80                     (LOTR2)  (Harry Potter1, Sixth Sense)
# 99                      (LOTR)     (Green Mile, Sixth Sense)
# 97                (Green Mile)           (LOTR, Sixth Sense)
# ..                         ...                           ...
# 5                (Sixth Sense)               (Harry Potter1)
# 55                 (Gladiator)     (Green Mile, Sixth Sense)
# 54   (Green Mile, Sixth Sense)                   (Gladiator)
# 21                (Green Mile)                   (Gladiator)
# 20                 (Gladiator)                  (Green Mile)
#
#      antecedent support  consequent support  support  confidence       lift  \
# 106                 0.1                 0.1      0.1    1.000000  10.000000
# 111                 0.1                 0.1      0.1    1.000000  10.000000
# ...

# %%
rules[rules.lift>1]
# Out:
#                      antecedents                  consequents  \
# 0                    (Gladiator)                (Sixth Sense)
# 1                  (Sixth Sense)                  (Gladiator)
# 6                      (Patriot)                (Sixth Sense)
# 7                  (Sixth Sense)                    (Patriot)
# 10                        (LOTR)                (Sixth Sense)
# ..                           ...                          ...
# 131  (Harry Potter1, Green Mile)                      (LOTR2)
# 132          (LOTR2, Green Mile)              (Harry Potter1)
# 133              (Harry Potter1)          (LOTR2, Green Mile)
# 134                      (LOTR2)  (Harry Potter1, Green Mile)
# 135                 (Green Mile)       (Harry Potter1, LOTR2)
#
#      antecedent support  consequent support  support  confidence      lift  \
# 0                   0.7                 0.6      0.5    0.714286  1.190476
# ...

# %%
rules=association_rules(frequent_items,metric="support",min_threshold=0.4)
rules
# Out:
#                  antecedents               consequents  antecedent support  \
# 0                (Gladiator)             (Sixth Sense)                 0.7
# 1              (Sixth Sense)               (Gladiator)                 0.6
# 2                  (Patriot)             (Sixth Sense)                 0.6
# 3              (Sixth Sense)                 (Patriot)                 0.6
# 4                (Gladiator)                 (Patriot)                 0.7
# 5                  (Patriot)               (Gladiator)                 0.6
# 6       (Gladiator, Patriot)             (Sixth Sense)                 0.6
# 7   (Gladiator, Sixth Sense)                 (Patriot)                 0.5
# 8     (Patriot, Sixth Sense)               (Gladiator)                 0.4
# 9                (Gladiator)    (Patriot, Sixth Sense)                 0.7
# 10                 (Patriot)  (Gladiator, Sixth Sense)                 0.6
# ...

# %%
rules=association_rules(frequent_items,metric="support",min_threshold=0.5)
rules
# Out:
#      antecedents    consequents  antecedent support  consequent support  \
# 0    (Gladiator)  (Sixth Sense)                 0.7                 0.6
# 1  (Sixth Sense)    (Gladiator)                 0.6                 0.7
# 2    (Gladiator)      (Patriot)                 0.7                 0.6
# 3      (Patriot)    (Gladiator)                 0.6                 0.7
#
#    support  confidence      lift  leverage  conviction
# 0      0.5    0.714286  1.190476      0.08         1.4
# 1      0.5    0.833333  1.190476      0.08         1.8
# 2      0.6    0.857143  1.428571      0.18         2.8
# 3      0.6    1.000000  1.428571      0.18         inf

# %%
rules=association_rules(frequent_items,metric="support",min_threshold=0.6)
rules
# Out:
#    antecedents  consequents  antecedent support  consequent support  support  \
# 0  (Gladiator)    (Patriot)                 0.7                 0.6      0.6
# 1    (Patriot)  (Gladiator)                 0.6                 0.7      0.6
#
#    confidence      lift  leverage  conviction
# 0    0.857143  1.428571      0.18         2.8
# 1    1.000000  1.428571      0.18         inf

# %%
rules=association_rules(frequent_items,metric="confidence",min_threshold=0.8)
rules
# Out:
#                      antecedents                consequents  \
# 0                  (Sixth Sense)                (Gladiator)
# 1                         (LOTR)              (Sixth Sense)
# 2                   (Green Mile)              (Sixth Sense)
# 3                    (Gladiator)                  (Patriot)
# 4                      (Patriot)                (Gladiator)
# 5                         (LOTR)                (Gladiator)
# 6                   (Braveheart)                (Gladiator)
# 7                        (LOTR1)                    (LOTR2)
# 8                        (LOTR2)                    (LOTR1)
# 9                (Harry Potter2)            (Harry Potter1)
# 10                  (Braveheart)                  (Patriot)
# 11                        (LOTR)               (Green Mile)
# 12      (Gladiator, Sixth Sense)                  (Patriot)
# 13        (Patriot, Sixth Sense)                (Gladiator)
# 14             (Gladiator, LOTR)              (Sixth Sense)
# ...

# %%
rules=association_rules(frequent_items,metric="confidence",min_threshold=0.9)
rules
# Out:
#                      antecedents                consequents  \
# 0                         (LOTR)              (Sixth Sense)
# 1                   (Green Mile)              (Sixth Sense)
# 2                      (Patriot)                (Gladiator)
# 3                         (LOTR)                (Gladiator)
# 4                   (Braveheart)                (Gladiator)
# 5                        (LOTR1)                    (LOTR2)
# 6                        (LOTR2)                    (LOTR1)
# 7                (Harry Potter2)            (Harry Potter1)
# 8                   (Braveheart)                  (Patriot)
# 9                         (LOTR)               (Green Mile)
# 10        (Patriot, Sixth Sense)                (Gladiator)
# 11             (Gladiator, LOTR)              (Sixth Sense)
# 12           (Sixth Sense, LOTR)                (Gladiator)
# 13                        (LOTR)   (Gladiator, Sixth Sense)
# 14       (Gladiator, Green Mile)              (Sixth Sense)
# ...

# %%
rules=association_rules(frequent_items,metric="confidence",min_threshold=1)
rules
# Out:
#                      antecedents                consequents  \
# 0                         (LOTR)              (Sixth Sense)
# 1                   (Green Mile)              (Sixth Sense)
# 2                      (Patriot)                (Gladiator)
# 3                         (LOTR)                (Gladiator)
# 4                   (Braveheart)                (Gladiator)
# 5                        (LOTR1)                    (LOTR2)
# 6                        (LOTR2)                    (LOTR1)
# 7                (Harry Potter2)            (Harry Potter1)
# 8                   (Braveheart)                  (Patriot)
# 9                         (LOTR)               (Green Mile)
# 10        (Patriot, Sixth Sense)                (Gladiator)
# 11             (Gladiator, LOTR)              (Sixth Sense)
# 12           (Sixth Sense, LOTR)                (Gladiator)
# 13                        (LOTR)   (Gladiator, Sixth Sense)
# 14       (Gladiator, Green Mile)              (Sixth Sense)
# ...

# %%
rules[rules.confidence==1]
# Out:
#                      antecedents                consequents  \
# 0                         (LOTR)              (Sixth Sense)
# 1                   (Green Mile)              (Sixth Sense)
# 2                      (Patriot)                (Gladiator)
# 3                         (LOTR)                (Gladiator)
# 4                   (Braveheart)                (Gladiator)
# 5                        (LOTR1)                    (LOTR2)
# 6                        (LOTR2)                    (LOTR1)
# 7                (Harry Potter2)            (Harry Potter1)
# 8                   (Braveheart)                  (Patriot)
# 9                         (LOTR)               (Green Mile)
# 10        (Patriot, Sixth Sense)                (Gladiator)
# 11             (Gladiator, LOTR)              (Sixth Sense)
# 12           (Sixth Sense, LOTR)                (Gladiator)
# 13                        (LOTR)   (Gladiator, Sixth Sense)
# 14       (Gladiator, Green Mile)              (Sixth Sense)
# ...
